# %% [markdown]
# # Q1. What is a probability distribution, exactly? If the values are meant to be random, how can you predict them at all?

# %% [markdown]
#  A probability distribution is a function that describes the likelihood of different outcomes in a random event. It provides a set of probabilities for each possible outcome. Although the individual values may be unpredictable, the overall distribution follows a specific pattern or rule.

# %% [markdown]
# # Q2. Is there a distinction between true random numbers and pseudo-random numbers, if there is one? Why are the latter considered “good enough”?

# %% [markdown]
# True random numbers are generated by natural events that are inherently unpredictable, such as atmospheric noise or radioactive decay. Pseudo-random numbers, on the other hand, are generated by an algorithm that produces a sequence of numbers that appear to be random but are actually deterministic. Pseudo-random numbers are considered "good enough" because they are statistically indistinguishable from true random numbers for most practical purposes.

# %% [markdown]
# # Q3. What are the two main factors that influence the behaviour of a &quot;normal&quot; probability distribution?

# %% [markdown]
# The two main factors that influence the behaviour of a normal probability distribution are the mean and the standard deviation. The mean determines the center of the distribution, while the standard deviation determines the spread or width of the distribution.

# %% [markdown]
# # Q4. Provide a real-life example of a normal distribution.

# %% [markdown]
# A real-life example of a normal distribution is the distribution of heights or weights in a population. In such cases, the distribution tends to be bell-shaped, with most values clustered around the mean and fewer values at the extremes.

# %% [markdown]
# # Q5. In the short term, how can you expect a probability distribution to behave? What do you think will happen as the number of trials grows?

# %% [markdown]
# In the short term, the behaviour of a probability distribution can be highly unpredictable. However, as the number of trials or observations increases, the distribution tends to converge towards its expected or theoretical values, according to the law of large numbers.

# %% [markdown]
# # Q6. What kind of object can be shuffled by using random.shuffle?

# %% [markdown]
# The random.shuffle function can shuffle any mutable sequence object in place, such as a list or an array.

# %% [markdown]
# # Q7. Describe the math package&#39;s general categories of functions.

# %% [markdown]
#  The math package's general categories of functions include basic arithmetic functions (e.g., addition, subtraction, multiplication, division), advanced mathematical functions (e.g., trigonometric, logarithmic, and exponential functions), and statistical functions (e.g., mean, standard deviation, probability distributions).

# %% [markdown]
# # Q8. What is the relationship between exponentiation and logarithms?

# %% [markdown]
# Exponentiation and logarithms are inverse mathematical operations. Exponentiation is the process of raising a base number to a given power, while logarithms are the inverse of exponentiation and tell us what power the base number must be raised to produce a given value.

# %% [markdown]
# # Q9. What are the three logarithmic functions that Python supports?

# %% [markdown]
# Python supports three logarithmic functions: math.log(x) for the natural logarithm (base e), math.log10(x) for the base-10 logarithm, and math.log2(x) for the base-2 logarithm.
